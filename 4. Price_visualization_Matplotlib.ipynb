# %% [markdown]
# # REAL_TIME series data Visualization

# %%
import selenium
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options # Hiding Browser

# visualization Purpose

import time
import matplotlib.pyplot as plt
from datetime import datetime
import seaborn as sns; sns.set()

import numpy as np
import pandas as pd
from IPython.display import display

# %%
# compile the STRING
# import re

# new_banana_pirce= []

# for j in prices_banana:
#     new_banana_pirce.append(float(j.replace('$', '')))
    
# new_banana_pirce

# %%
# %matplotlib notebook
plt.rcParams['animation.html']= 'jshtml'

# %%
# create subplot
fig= plt.figure()
ax= fig.add_subplot(111)

fig.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Setting up environment
#
# # PRICE -> y axis
# # TIME -> x-axis

# %%
# option= Options()
# option.add_argument("--headless")

# brow= webdriver.Chrome( options= option)
# #brow= webdriver.Chrome()
# #brow.get('https://apeswap.finance/')

# brow.get('https://info.apeswap.finance/token/0x603c7f932ed1fc6575303d8fb018fdcbb0f39a95')

# # waiting time
# brow.implicitly_wait(10)

# #/html/body/div/div/div/div[2]/div/div[3]/div[2]/div/div[2]/div[1]/div/div[2]/div[1]

# ape_price= brow.find_element_by_xpath('//*[@id="center"]/div/div[3]/div[2]/div/div[2]/div[1]/div/div[2]')

# #ape_price= brow.find_element_by_xpath('/html/body/div/div/div/div[2]/div/div[3]/div[2]/div/div[2]/div[1]/div/div[2]/div[1]')

# # ApeSwap price
# #price_ap= float(ape_price.text[1:])    

# print('Price: ',ape_price )
# Out:
# Price:  <selenium.webdriver.remote.webelement.WebElement (session="88196914051eb310e1f7d8c632af7b46", element="612a61fe-716a-4e6b-a155-cd67a66fe274")>

# %%
# suprassing (Hiding) Browser from popping

option= Options()
option.add_argument("--headless")

# assignment

i= 0

y= [] # apeSwap Price
y1= [] # Bscan Price
x= []

# ApeSWAP
brow= webdriver.Chrome( options= option)
#brow= webdriver.Chrome()
#brow.get('https://apeswap.finance/')
brow.get('https://info.apeswap.finance/token/0x603c7f932ed1fc6575303d8fb018fdcbb0f39a95')


# waiting time for browser
brow.implicitly_wait(10)


# setting  Browser option
# BsCan website

browser= webdriver.Chrome(options= option)
#browser= webdriver.Chrome()
browser.get('https://bscscan.com/token/0x603c7f932ed1fc6575303d8fb018fdcbb0f39a95')

# implicit watiing time
browser.implicitly_wait(10)
c=0 


# LABELING the graph prices
ax.set_ylabel('Ape')

while True:
   
    # Empty list
    prices_banana= []   
    
    # empty list for BScan
    price_bscan= []
    
    
    
    # ApaeSwap
    #ape_price= brow.find_element_by_xpath('//*[@id="root"]/div[1]/div/div[1]/div[2]/div[1]/a/div')   
    
    
    ape_price= brow.find_element_by_xpath('//*[@id="center"]/div/div[3]/div[2]/div/div[2]/div[1]/div/div[2]/div[1]')

    # BscScan
    dbscan_price= browser.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tr_valuepertoken"]/div/div[1]/span')
    
    
    time.sleep(.20)

    # ApeSwap price
    price_ap= float(ape_price.text[1:])    
    
    # individual price from BSCAN
    price_bsc= float(dbscan_price.text[1:7])

    # RPICE
    # Add the new prices of ApeSwap
    y.append(price_ap)

    # Add the NEW price of BSCAN
    y1.append(price_bsc)
    # TIME
    #x.append(datetime.now())
    x.append(i)
    
    # TWO plots
    ax.plot(x, y, color ='b', label='ApeSwap')
    ax.plot(x, y1, color= 'r', label='BsScan')
   # ax.legend(loc='upper left', frameon= False)
    fig.canvas.draw()

    # setting NO limit 
    ax.set_xlim(left= max(0, i-20), right= i+20)


    time.sleep(0.5)
    i +=1
    
# close browser
# brow.quit()
# browser.quit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-e657de5e3b08> in <module>
#      61
#      62     # ApeSwap price
# ---> 63     price_ap= float(ape_price.text[1:])
#      64
#      65     # individual price from BSCAN
#
# ValueError: could not convert string to float: '7,396,207'

# %%
#print(datetime.now())

# %% [markdown]
# # PLOT from BSCAN

# %%
# browser= Chrome()
# browser.get('https://bscscan.com/token/0x603c7f932ed1fc6575303d8fb018fdcbb0f39a95')

# # implicit watiing time
# browser.implicitly_wait(10)

# dbscan_price= browser.find_element_by_xpath('//*[@id="ContentPlaceHolder1_tr_valuepertoken"]/div/div[1]/span')
# print(dbscan_price.text[1:7])

# browser.close()

# %% [markdown]
# # ApaeSwap

# %%
# brow= Chrome()
# brow.get('https://apeswap.finance/')

# # waiting time for browser
# brow.implicitly_wait(10)
# p= brow.find_element_by_xpath('//*[@id="root"]/div[1]/div/div[1]/div[2]/div[1]/a')

# price= float(p.text[1:])

# print (price)
# brow.close()
